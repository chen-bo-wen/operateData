# %% [markdown]
# [模型下载路径](https://github.com/open-mmlab/mmcv/blob/master/mmcv/model_zoo/open_mmlab.json)

# %% [markdown]
# [训练自定义数据集](https://mmdetection.readthedocs.io/en/latest/user_guides/train.html#train-with-customized-datasets)
# ，但是不记得之前是如何制作出自己的数据集了，需要后续再看看。

# %% [markdown]
# 训练自己的数据集代码：
#
# 训练文件路径：/App/cbw/mmdetection-main/tools/train.py

# %%
# python /App/cbw/mmdetection-main/tools/train.py \
# /App/cbw/mmdetection-main/configs/mask_rcnn/mask-rcnn_r50-caffe_fpn_ms-poly-3x_hualu.py \
# --work-dir '/App/cbw/mmdetection-main/work_dirs/new_new_mask-rcnn_r50-caffe_fpn_ms-poly-3x_hualu'

# %% [markdown]
# 数据处理：
