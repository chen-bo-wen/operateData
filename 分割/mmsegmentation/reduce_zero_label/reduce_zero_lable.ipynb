# %% [markdown]
# ADE 数据集

# %% [markdown]
# 只要用到 dict(type='LoadAnnotations' 的，都要进行设置检查。
#
# 设置的 class 在该文件里：mmsegmentation-main/mmseg/datasets/transforms/loading.py

# %% [markdown]
# ![1.png](1.png)
#
# 另一个文件里：
#
# ![2.png](2.png)
