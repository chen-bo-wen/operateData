# %%
将原文件生成 instances_train2017.json 和 instances_val2017.json 格式的

通过 labelme-main 代码库： labelme-main/examples/instance_segmentation

分为 coco格式的 和 voc格式的

/App/cbw/labelme-main/examples/instance_segmentation/labelme2coco.py 生成 coco格式的。。。
运行命令：
# python /App/cbw/labelme-main/examples/instance_segmentation/labelme2coco.py \
# --labels label.txt \
# --input_dir 'Labels' \
# --output_dir 'output_dir'

可以修改：
        # out_img_file = osp.join(args.output_dir, "JPEGImages", base + ".jpg")
        out_img_file = osp.join(args.output_dir, "JPEGImages", base + ".png")
