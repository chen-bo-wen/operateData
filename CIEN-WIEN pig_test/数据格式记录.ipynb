# %% [markdown]
# "annotations": [{"id": 1, "iscrowd": 0, "image_id": 1, "category_id": 1, "segmentation": [[528.0, 234.0, 517.0, 230.0, 513.0, 231.0, 509.0, 231.0, 502.0, 234.0, 483.0, 250.0, 474.0, 265.0, 467.0, 272.0, 447.0, 280.0, 434.0, 289.0, 425.0, 298.0, 392.0, 357.0, 382.0, 371.0, 369.0, 386.0, 359.0, 411.0, 357.0, 424.0, 357.0, 434.0, 351.0, 451.0, 347.0, 454.0, 332.0, 457.0, 324.0, 465.0, 320.0, 476.0, 316.0, 481.0, 315.0, 489.0, 319.0, 493.0, 334.0, 497.0, 340.0, 496.0, 341.0, 495.0, 345.0, 495.0, 347.0, 499.0, 345.0, 501.0, 343.0, 506.0, 341.0, 516.0, 341.0, 524.0, 346.0, 533.0, 356.0, 533.0, 358.0, 531.0, 359.0, 531.0, 368.0, 519.0, 374.0, 514.0, 377.0, 515.0, 378.0, 519.0, 386.0, 536.0, 392.0, 543.0, 393.0, 543.0, 395.0, 545.0, 402.0, 545.0, 409.0, 537.0, 409.0, 505.0, 404.0, 492.0, 399.0, 489.0, 397.0, 489.0, 395.0, 488.0, 392.0, 485.0, 393.0, 479.0, 401.0, 472.0, 421.0, 459.0, 434.0, 443.0, 448.0, 415.0, 482.0, 378.0, 496.0, 358.0, 497.0, 355.0, 501.0, 349.0, 507.0, 343.0, 516.0, 340.0, 526.0, 335.0, 538.0, 324.0, 548.0, 306.0, 552.0, 292.0, 550.0, 280.0, 550.0, 272.0, 552.0, 263.0, 544.0, 255.0, 542.0, 249.0, 536.0, 241.0]], "area": 27160.0, "bbox": [315.0, 230.0, 237.0, 315.0]},
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio==0.8.1 -f  /App/cbw/CIEN-LWEN-main/cu111/torch-1.8.1%2Bcu111-cp37-cp37m-linux_x86_64.whl
#
# python GT_test.py --config_file default_LWEN --dataset mini_LISAP_test --checkpoint data/default_LWEN.pth
#
# python SEG_test.py --config_file default_LWEN --dataset mini_LISAP_test --checkpoint data/Trained_LWEN.pth --seg_results /App/cbw/CIEN-LWEN-main/CIEN/data/result/default_CIEN/py_results_with_ID_and_Weight.json
#
# python test.py --config_file default_CIEN --dataset mini_LISAP_test --with_nms True
#
#
# 在 README 里记录了这个：
# Note: There are total 39 pigs in weight_data.csv. In LISAP, we only annotated No.27~39,
# because others pigs were kept in other pens(the installation height were a little different). And No.40 means the indeterminate ID.
#
# CIEN：查看生成的 img_results_with_ID_and_Weight.json 文件、py_results_with_ID_and_Weight.json 文件，里面的 category_id 只有 27~39.
# LWEN：查看生成的 results.json 文件，里面的 category_id 只有 27~39.
#              查看生成的 stat_results.json 文件，里面也只有 27~39.
#
#
# 训练使用的文件：
# CIEN：使用的是 Class_agnostic_annotations.json 后缀的文件 （在 info.py 文件里定义）
# LWEN：使用的是 annotations.json 后缀的文件（在 dataset_catalog.py 文件里定义）
