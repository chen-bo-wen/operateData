# %% [markdown]
# <div id='top'>包括以下操作：</div>
# <li><a href='#1'>安装 CUDA</a></li>
# <li><a href='#2'>安装 cuDNN</a></li>
# <li><a href='#3'></a></li>
# <li><a href='#4'></a></li>
# <li><a href='#5'></a></li>
# <li><a href='#6'></a></li>

# %% [markdown]
# 根据对应 CUDA 版本安装 pytorch、torchvision、torchaudio
#
# https://pytorch.org/get-started/previous-versions/

# %% [markdown]
# 安装CUDA Toolkit Archive
#
# https://developer.nvidia.com/cuda-toolkit-archive

# %% [markdown]
# 安装 cuDNN Archive
#
# https://developer.nvidia.com/cudnn-archive
#
# cuDNN安装包：https://developer.download.nvidia.com/compute/cudnn/redist/cudnn/linux-x86_64/

# %% [markdown]
# 安装 torch：
# https://download.pytorch.org/whl/torch_stable.html
#
# 针对cu111的：https://download.pytorch.org/whl/cu111/torch_stable.html?login=from_csdn

# %% [markdown]
# 清华镜像
#
# https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud/pytorch/win-64/

# %% [markdown]
# <div style='color:skyblue; font-size:24px' id='1'>安装CUDA</div>
#
# <a href='#top'>▲ Top</a>

# %% [markdown]
# ![1.png](1.png)
# ![2.png](2.png)

# %%
nvcc -V

查看所有CUDA安装： 
ls -l /usr/local | grep cuda

sudo rm /usr/local/cuda # 删除现有符号链接，如果存在的话
sudo ln -sf /usr/local/cuda-12.4 /usr/local/cuda

# cuda path
# export PATH=/usr/local/cuda-10.2/bin${PATH:+:${PATH}}
# export LD_LIBRARY_PATH=/usr/local/cuda-10.2/lib64${LD_LIBRARY_PATH:+:${LD_LIBRARY_PATH}}
# export CUDA_HOME=/usr/local/cuda-10.2

export PATH=/usr/local/cuda/bin${PATH:+:${PATH}}
export LD_LIBRARY_PATH=/usr/local/cuda/lib64${LD_LIBRARY_PATH:+:${LD_LIBRARY_PATH}}
export CUDA_HOME=/usr/local/cuda

# %% [markdown]
# ![3.png](3.png)

# %% [markdown]
# <div style='color:skyblue; font-size:24px' id='2'>安装 cuDNN</div>
#
# <a href='#top'>▲ Top</a>
#
# 需要使用的 root 账号，即当 type -a pip 时，第一不能显示的是当前的虚拟环境

# %%
# 安装 cuDNN（需要使用的 root 账号，即当 type -a pip 时，第一不能显示的是当前的虚拟环境）
# 先去下载对应的 .tar 压缩包？？或 在线下载（下面第一行代码）
wget -c https://developer.download.nvidia.com/compute/redist/cudnn/v8.7.0/local_installers/11.8/cudnn-linux-x86_64-8.7.0.84_cuda11-archive.tar.xz

xz -dk cudnn-linux-x86_64-8.7.0.84_cuda11-archive.tar.xz
tar -xvf cudnn-linux-x86_64-8.7.0.84_cuda11-archive.tar
cd cudnn-linux-x86_64-8.7.0.84_cuda11-archive
sudo cp ./lib/* /usr/local/cuda-11.8/lib64/
sudo cp ./include/* /usr/local/cuda-11.8/include/
