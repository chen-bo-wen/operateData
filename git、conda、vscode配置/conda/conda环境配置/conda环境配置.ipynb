# %% [markdown]
# 在创建虚拟环境时，指定 python 版本：(否则的话很有可能就是创建的 python3)

# %%
conda create -n myenv python=3.8

# %% [markdown]
# 已经安装了 python/python3，需要安装 pip:

# %%
curl https://bootstrap.pypa.io/get-pip.py -o get-pip.py

python get-pip.py

# %% [markdown]
# 确保安装在正确的路径里：

# %%
python -m pip install [module]
python -m pip install .

# %% [markdown]
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
#
# ![1.png](1.png)

# %% [markdown]
# 当终端显示如上错误的时候，考虑版本的兼容问题；如 opencv-python==4.5.1.48 和 python 3.13 不兼容，就可能出现上述错误。

# %% [markdown]
# ### opencv-python

# %%
python版本为3.7.0
######### 是不是和 qt 的版本也相关，如何查看 qt 版本路径？？？？？？？？？？？？？？？？
当安装版本为 4.5.1.48 就报错：
Got keys from plugin meta data ("xcb")
QFactoryLoader::QFactoryLoader() checking directory path "/home/huazhi/anaconda3/envs/ste/bin/platforms" ...
loaded library "/home/huazhi/anaconda3/envs/ste/lib/python3.7/site-packages/cv2/qt/plugins/platforms/libqxcb.so"
qt.qpa.xcb: could not connect to display 
qt.qpa.plugin: Could not load the Qt platform plugin "xcb" in "/home/huazhi/anaconda3/envs/ste/lib/python3.7/site-packages/cv2/qt/plugins" even though it was found.
This application failed to start because no Qt platform plugin could be initialized. Reinstalling the application may fix this problem.

Available platform plugins are: xcb.

Aborted (core dumped)

当安装版本为 4.1.2.30 时就报错 cannot connect to X server
