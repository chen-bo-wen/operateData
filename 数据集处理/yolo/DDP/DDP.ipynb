# %% [markdown]
# ![1.png](1.png)

# %% [markdown]
# 遇到上述这种问题，是分布式训练报错：device = [0,1,2,3]。考虑换命令：
# 新版的：
# torchrun --nproc_per_node=4 --master_port=57327 trainSeedDDP.py \
#   --data /App/lpl/chongcao_yolo11/FY_2_project/datasets.yaml \
#   --imgsz 640 \
#   --device 0,1,2,3 \
#   --project /App/lpl/chongcao_yolo11/runs/train \
#   --name exp
#
#
#
# 之前旧版本的：
# CUDA_VISIBLE_DEVICES='0,1,2,3' python -m torch.distributed.launch --master_port=29507 --nproc_per_node=4 --use_env yolo_train_FY.py \
#   --imgsz 1080 \
#   --epochs 50 \
#   --batch 4 \
#   --workers 4 \
#   --device 0,1,2,3
